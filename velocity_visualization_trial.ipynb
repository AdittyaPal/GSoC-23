# %%
from tardis import run_tardis

sim = run_tardis("uniform_ejecta_model_type_II.yml", virtual_packet_logging=True)
# Out:
# ---------------------------------------------------------------------------
# ScannerError                              Traceback (most recent call last)
# Cell In[3], line 3
#       1 from tardis import run_tardis
# ----> 3 sim = run_tardis("uniform_ejecta_model_type_II.yml", virtual_packet_logging=True)
#
# File ~/miniconda3/envs/tardis/lib/python3.8/site-packages/tardis/base.py:82, in run_tardis(config, atom_data, packet_source, simulation_callbacks, virtual_packet_logging, show_convergence_plots, log_level, specific_log_level, show_progress_bars, **kwargs)
#      80 else:
#      81     try:
# ---> 82         tardis_config = Configuration.from_yaml(config)
#      83     except TypeError:
#      84         logger.debug(
#      85             "TARDIS Config not available via YAML. Reading through TARDIS Config Dictionary"
#      86         )
#
# ...
